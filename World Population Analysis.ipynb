# %% [markdown]
# # Importing drive and essential Libraries

# %%
#import google drive
from google.colab import drive
print('successfully imported')
# Out:
# successfully imported

# %%
#mounting drive
drive.mount('/content/drive')
print('successfully mounted')
# Out:
# Mounted at /content/drive
# successfully mounted

# %%
#install pmdarima
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (3.0.11)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (2.1.4)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.3.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.13.1)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (0.14.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (2.0.7)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (71.0.4)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Downloading pmdarima-2.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 32.4 MB/s eta 0:00:00
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.0.4

# %%
#importing essential libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pmdarima as pm
import warnings
warnings.filterwarnings('ignore')
print('successfully imported')
# Out:
# successfully imported

# %% [markdown]
# # Loading the datasets

# %%
#loading country_data
country_data = pd.read_csv('/content/drive/MyDrive/Data Science/World pop/country_data.csv')
print('successfully loaded')
# Out:
# successfully loaded

# %%
#loading world_data
world_data = pd.read_csv('/content/drive/MyDrive/Data Science/World pop/world_pop.csv')
print('successfully loaded')
# Out:
# successfully loaded

# %%
#top rows o country_data dataset
country_data.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  "26 countries, stretching from the Red Sea in ...
# 2  Fiscal year end: March 20; reporting period fo...
# 3  "22 countries, stretching from the westernmost...
# 4                                                NaN
#
#                      TableName
# 0                        Aruba
# 1  Africa Eastern and Southern
# 2                  Afghanistan
# 3   Africa Western and Central
# 4                       Angola

# %%
#top rows of world_data dataset
world_data.head()
# Out:
#   Country Code       Indicator Name Indicator Code         1960         1961  \
# 0          ABW  "Population, total"    SP.POP.TOTL      54208.0      55434.0
# 1          AFE  "Population, total"    SP.POP.TOTL  130836765.0  134159786.0
# 2          AFG  "Population, total"    SP.POP.TOTL    8996967.0    9169406.0
# 3          AFW  "Population, total"    SP.POP.TOTL   96396419.0   98407221.0
# 4          AGO  "Population, total"    SP.POP.TOTL    5454938.0    5531451.0
#
#           1962         1963         1964         1965         1966  ...  \
# 0      56234.0      56699.0      57029.0      57357.0      57702.0  ...
# 1  137614644.0  141202036.0  144920186.0  148769974.0  152752671.0  ...
# 2    9351442.0    9543200.0    9744772.0    9956318.0   10174840.0  ...
# 3  100506960.0  102691339.0  104953470.0  107289875.0  109701811.0  ...
# 4    5608499.0    5679409.0    5734995.0    5770573.0    5781305.0  ...
#
#           2011         2012         2013         2014         2015  \
# 0     102050.0     102565.0     103165.0     103776.0     104339.0
# 1  532760424.0  547482863.0  562601578.0  578075373.0  593871847.0
# 2   30117411.0   31161378.0   32269592.0   33370804.0   34413603.0
# 3  360285439.0  370243017.0  380437896.0  390882979.0  401586651.0
# 4   24220660.0   25107925.0   26015786.0   26941773.0   27884380.0
#
#           2016         2017         2018         2019         2020
# 0     104865.0     105361.0     105846.0     106310.0     106766.0
# 1  609978946.0  626392880.0  643090131.0  660046272.0  677243299.0
# 2   35383028.0   36296111.0   37171922.0   38041757.0   38928341.0
# 3  412551299.0  423769930.0  435229381.0  446911598.0  458803476.0
# 4   28842482.0   29816769.0   30809787.0   31825299.0   32866268.0
#
# [5 rows x 64 columns]

# %% [markdown]
# # Data Wrangling

# %%
#examining the shape of this dataset
country_data.shape
print(f'country_data has {country_data.shape[0]} rows and {country_data.shape[1]} columns')
# Out:
# country_data has 265 rows and 5 columns

# %%
#examining the shape of this dataset
world_data.shape
print(f'world_data has {world_data.shape[0]} rows and {world_data.shape[1]} columns')
# Out:
# world_data has 266 rows and 64 columns

# %%
#listing out the columns
country_data.columns
# Out:
# Index(['Country Code', 'Region', 'IncomeGroup', 'SpecialNotes', 'TableName'], dtype='object')

# %%
#listing out the columns
world_data.columns
# Out:
# Index(['Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961',
#        '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970',
#        '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979',
#        '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
#exploring the column 'Indicator name' to see its relevance
#It can be deduced that the values in the column is of no relevance to this analysis#
world_data['Indicator Name'].unique()
# Out:
# array(['"Population, total"'], dtype=object)

# %%
#droppping columns 'Indicator name' and 'Indicator code'
world_data.drop(['Indicator Name','Indicator Code'],axis=1,inplace=True)

# %%
#confirming that the columns have been dropped
world_data.head()
# Out:
#   Country Code         1960         1961         1962         1963  \
# 0          ABW      54208.0      55434.0      56234.0      56699.0
# 1          AFE  130836765.0  134159786.0  137614644.0  141202036.0
# 2          AFG    8996967.0    9169406.0    9351442.0    9543200.0
# 3          AFW   96396419.0   98407221.0  100506960.0  102691339.0
# 4          AGO    5454938.0    5531451.0    5608499.0    5679409.0
#
#           1964         1965         1966         1967         1968  ...  \
# 0      57029.0      57357.0      57702.0      58044.0      58377.0  ...
# 1  144920186.0  148769974.0  152752671.0  156876454.0  161156430.0  ...
# 2    9744772.0    9956318.0   10174840.0   10399936.0   10637064.0  ...
# 3  104953470.0  107289875.0  109701811.0  112195950.0  114781116.0  ...
# 4    5734995.0    5770573.0    5781305.0    5774440.0    5771973.0  ...
#
#           2011         2012         2013         2014         2015  \
# 0     102050.0     102565.0     103165.0     103776.0     104339.0
# 1  532760424.0  547482863.0  562601578.0  578075373.0  593871847.0
# 2   30117411.0   31161378.0   32269592.0   33370804.0   34413603.0
# 3  360285439.0  370243017.0  380437896.0  390882979.0  401586651.0
# 4   24220660.0   25107925.0   26015786.0   26941773.0   27884380.0
#
#           2016         2017         2018         2019         2020
# 0     104865.0     105361.0     105846.0     106310.0     106766.0
# 1  609978946.0  626392880.0  643090131.0  660046272.0  677243299.0
# 2   35383028.0   36296111.0   37171922.0   38041757.0   38928341.0
# 3  412551299.0  423769930.0  435229381.0  446911598.0  458803476.0
# 4   28842482.0   29816769.0   30809787.0   31825299.0   32866268.0
#
# [5 rows x 62 columns]

# %%
#dropping column 'SpecialNotes' from country_data
country_data.drop(['SpecialNotes'], axis=1, inplace=True)

# %%
#confirming the above column has been dropped
country_data.head(10)
# Out:
#   Country Code                      Region          IncomeGroup  \
# 0          ABW   Latin America & Caribbean          High income
# 1          AFE                         NaN                  NaN
# 2          AFG                  South Asia           Low income
# 3          AFW                         NaN                  NaN
# 4          AGO          Sub-Saharan Africa  Lower middle income
# 5          ALB       Europe & Central Asia  Upper middle income
# 6          AND       Europe & Central Asia          High income
# 7          ARB                         NaN                  NaN
# 8          ARE  Middle East & North Africa          High income
# 9          ARG   Latin America & Caribbean  Upper middle income
#
#                      TableName
# 0                        Aruba
# 1  Africa Eastern and Southern
# 2                  Afghanistan
# 3   Africa Western and Central
# 4                       Angola
# 5                      Albania
# 6                      Andorra
# 7                   Arab World
# 8         United Arab Emirates
# 9                    Argentina

# %%
#merging country_data and world_data
df = pd.merge(country_data, world_data, on='Country Code', how = 'right')
df.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                      TableName         1960         1961         1962  \
# 0                        Aruba      54208.0      55434.0      56234.0
# 1  Africa Eastern and Southern  130836765.0  134159786.0  137614644.0
# 2                  Afghanistan    8996967.0    9169406.0    9351442.0
# 3   Africa Western and Central   96396419.0   98407221.0  100506960.0
# 4                       Angola    5454938.0    5531451.0    5608499.0
#
#           1963         1964         1965  ...         2011         2012  \
# 0      56699.0      57029.0      57357.0  ...     102050.0     102565.0
# 1  141202036.0  144920186.0  148769974.0  ...  532760424.0  547482863.0
# 2    9543200.0    9744772.0    9956318.0  ...   30117411.0   31161378.0
# 3  102691339.0  104953470.0  107289875.0  ...  360285439.0  370243017.0
# 4    5679409.0    5734995.0    5770573.0  ...   24220660.0   25107925.0
#
#           2013         2014         2015         2016         2017  \
# 0     103165.0     103776.0     104339.0     104865.0     105361.0
# 1  562601578.0  578075373.0  593871847.0  609978946.0  626392880.0
# 2   32269592.0   33370804.0   34413603.0   35383028.0   36296111.0
# 3  380437896.0  390882979.0  401586651.0  412551299.0  423769930.0
# 4   26015786.0   26941773.0   27884380.0   28842482.0   29816769.0
#
#           2018         2019         2020
# 0     105846.0     106310.0     106766.0
# 1  643090131.0  660046272.0  677243299.0
# 2   37171922.0   38041757.0   38928341.0
# 3  435229381.0  446911598.0  458803476.0
# 4   30809787.0   31825299.0   32866268.0
#
# [5 rows x 65 columns]

# %%
#shape of new dataset "df"
df.shape
# Out:
# (266, 65)

# %%
#checking for new dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 65 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  266 non-null    object
#  1   Region        217 non-null    object
#  2   IncomeGroup   216 non-null    object
#  3   TableName     265 non-null    object
#  4   1960          264 non-null    float64
#  5   1961          264 non-null    float64
#  6   1962          264 non-null    float64
#  7   1963          264 non-null    float64
#  8   1964          264 non-null    float64
#  9   1965          264 non-null    float64
#  10  1966          264 non-null    float64
#  11  1967          264 non-null    float64
#  12  1968          264 non-null    float64
#  13  1969          264 non-null    float64
#  14  1970          264 non-null    float64
#  15  1971          264 non-null    float64
#  16  1972          264 non-null    float64
#  17  1973          264 non-null    float64
#  18  1974          264 non-null    float64
#  19  1975          264 non-null    float64
#  20  1976          264 non-null    float64
#  21  1977          264 non-null    float64
#  22  1978          264 non-null    float64
#  23  1979          264 non-null    float64
#  24  1980          264 non-null    float64
#  25  1981          264 non-null    float64
#  26  1982          264 non-null    float64
#  27  1983          264 non-null    float64
#  28  1984          264 non-null    float64
#  29  1985          264 non-null    float64
#  30  1986          264 non-null    float64
#  31  1987          264 non-null    float64
#  32  1988          264 non-null    float64
#  33  1989          264 non-null    float64
#  34  1990          265 non-null    float64
#  35  1991          265 non-null    float64
#  36  1992          264 non-null    float64
#  37  1993          264 non-null    float64
#  38  1994          264 non-null    float64
#  39  1995          265 non-null    float64
#  40  1996          265 non-null    float64
#  41  1997          265 non-null    float64
#  42  1998          265 non-null    float64
#  43  1999          265 non-null    float64
#  44  2000          265 non-null    float64
#  45  2001          265 non-null    float64
#  46  2002          265 non-null    float64
#  47  2003          265 non-null    float64
#  48  2004          265 non-null    float64
#  49  2005          265 non-null    float64
#  50  2006          265 non-null    float64
#  51  2007          265 non-null    float64
#  52  2008          265 non-null    float64
#  53  2009          265 non-null    float64
#  54  2010          265 non-null    float64
#  55  2011          265 non-null    float64
#  56  2012          264 non-null    float64
#  57  2013          264 non-null    float64
#  58  2014          264 non-null    float64
#  59  2015          264 non-null    float64
#  60  2016          264 non-null    float64
#  61  2017          264 non-null    float64
#  62  2018          264 non-null    float64
#  63  2019          264 non-null    float64
#  64  2020          264 non-null    float64
# dtypes: float64(61), object(4)
# memory usage: 135.2+ KB

# %%
#filtering out Nigeria data
Nigeria_df = df[df['TableName']== 'Nigeria']
Nigeria_df.head()
# Out:
#     Country Code              Region          IncomeGroup TableName  \
# 174          NGA  Sub-Saharan Africa  Lower middle income   Nigeria
#
#            1960        1961        1962        1963        1964        1965  \
# 174  45138460.0  46063570.0  47029818.0  48032932.0  49066762.0  50127920.0
#
#      ...         2011         2012         2013         2014         2015  \
# 174  ...  162805080.0  167228803.0  171765819.0  176404931.0  181137454.0
#
#             2016         2017         2018         2019         2020
# 174  185960244.0  190873247.0  195874685.0  200963603.0  206139587.0
#
# [1 rows x 65 columns]

# %%
#dropping redundant columns from Nigeria data
Nigeria_df.drop(['Country Code', 'Region', 'IncomeGroup'], axis=1, inplace=True)

# %%
#veryfing above columns have been dropped
Nigeria_df
# Out:
#     TableName        1960        1961        1962        1963        1964  \
# 174   Nigeria  45138460.0  46063570.0  47029818.0  48032932.0  49066762.0
#
#            1965        1966        1967        1968  ...         2011  \
# 174  50127920.0  51217969.0  52342231.0  53506201.0  ...  162805080.0
#
#             2012         2013         2014         2015         2016  \
# 174  167228803.0  171765819.0  176404931.0  181137454.0  185960244.0
#
#             2017         2018         2019         2020
# 174  190873247.0  195874685.0  200963603.0  206139587.0
#
# [1 rows x 62 columns]

# %%
#reset index, drop columns and transpose years
Naija_df = Nigeria_df.reset_index(drop=True).drop(columns=['TableName']).T
Naija_df.head()
# Out:
#                0
# 1960  45138460.0
# 1961  46063570.0
# 1962  47029818.0
# 1963  48032932.0
# 1964  49066762.0

# %%
#reset index
Naija_df.reset_index(inplace=True)

# %%
#top rows
Naija_df.head()
# Out:
#   index           0
# 0  1960  45138460.0
# 1  1961  46063570.0
# 2  1962  47029818.0
# 3  1963  48032932.0
# 4  1964  49066762.0

# %%
#rename columns
Naija_df.rename(columns={'index': 'Year', 0: 'Population'}, inplace=True)
Naija_df.head()
# Out:
#    Year  Population
# 0  1960  45138460.0
# 1  1961  46063570.0
# 2  1962  47029818.0
# 3  1963  48032932.0
# 4  1964  49066762.0

# %%
#check data types
Naija_df.dtypes
# Out:
# Year           object
# Population    float64
# dtype: object

# %%
#change Year data type
Naija_df['Year'] = pd.to_datetime(Naija_df['Year']).dt.year

# %%
Naija_df.dtypes
# Out:
# Year            int32
# Population    float64
# dtype: object

# %%
#max value in year
Naija_df['Year'].max()
# Out:
# 2020

# %%
#min value in Year
Naija_df['Year'].min()
# Out:
# 1960

# %%
#checking for null values
Naija_df.isnull().sum()
# Out:
# Year          0
# Population    0
# dtype: int64

# %%
Naija_df.shape
# Out:
# (61, 2)

# %%
#creating boxplots to determine the presence of outliers
sns.boxplot(y='Population', data=Naija_df)
plt.title('Boxplot of Population\n')
plt.show()

# %%
#exploring the distribution of the data
sns.distplot(Naija_df['Population'], kde = True)
plt.title('Distribution of Population\n')
plt.show()

# %%
#exploring the skewness of 'Population' data
Naija_df['Population'].skew()
# Out:
# 0.5630637789908473

# %%
#checking for the trend of population increase with respect to year
Naija_df.plot('Year', 'Population')
plt.title('Nigeria Population Trend\n')
plt.show()

# %% [markdown]
# # Data Analysis

# %% [markdown]
# 1. •	Which country and region has experienced the highest percentage of population growth in last 60 years

# %%
#looking into our dataset#
df.head(5)
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                      TableName         1960         1961         1962  \
# 0                        Aruba      54208.0      55434.0      56234.0
# 1  Africa Eastern and Southern  130836765.0  134159786.0  137614644.0
# 2                  Afghanistan    8996967.0    9169406.0    9351442.0
# 3   Africa Western and Central   96396419.0   98407221.0  100506960.0
# 4                       Angola    5454938.0    5531451.0    5608499.0
#
#           1963         1964         1965  ...         2011         2012  \
# 0      56699.0      57029.0      57357.0  ...     102050.0     102565.0
# 1  141202036.0  144920186.0  148769974.0  ...  532760424.0  547482863.0
# 2    9543200.0    9744772.0    9956318.0  ...   30117411.0   31161378.0
# 3  102691339.0  104953470.0  107289875.0  ...  360285439.0  370243017.0
# 4    5679409.0    5734995.0    5770573.0  ...   24220660.0   25107925.0
#
#           2013         2014         2015         2016         2017  \
# 0     103165.0     103776.0     104339.0     104865.0     105361.0
# 1  562601578.0  578075373.0  593871847.0  609978946.0  626392880.0
# 2   32269592.0   33370804.0   34413603.0   35383028.0   36296111.0
# 3  380437896.0  390882979.0  401586651.0  412551299.0  423769930.0
# 4   26015786.0   26941773.0   27884380.0   28842482.0   29816769.0
#
#           2018         2019         2020
# 0     105846.0     106310.0     106766.0
# 1  643090131.0  660046272.0  677243299.0
# 2   37171922.0   38041757.0   38928341.0
# 3  435229381.0  446911598.0  458803476.0
# 4   30809787.0   31825299.0   32866268.0
#
# [5 rows x 65 columns]

# %%
#creating a new column showing the difference between year 2020 and 1960 population#
df['pop_growth'] = df['2020'] - df['1960']

# %%
#rechecking our dataset for the new column added#
df.head(5)
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                      TableName         1960         1961         1962  \
# 0                        Aruba      54208.0      55434.0      56234.0
# 1  Africa Eastern and Southern  130836765.0  134159786.0  137614644.0
# 2                  Afghanistan    8996967.0    9169406.0    9351442.0
# 3   Africa Western and Central   96396419.0   98407221.0  100506960.0
# 4                       Angola    5454938.0    5531451.0    5608499.0
#
#           1963         1964         1965  ...         2012         2013  \
# 0      56699.0      57029.0      57357.0  ...     102565.0     103165.0
# 1  141202036.0  144920186.0  148769974.0  ...  547482863.0  562601578.0
# 2    9543200.0    9744772.0    9956318.0  ...   31161378.0   32269592.0
# 3  102691339.0  104953470.0  107289875.0  ...  370243017.0  380437896.0
# 4    5679409.0    5734995.0    5770573.0  ...   25107925.0   26015786.0
#
#           2014         2015         2016         2017         2018  \
# 0     103776.0     104339.0     104865.0     105361.0     105846.0
# 1  578075373.0  593871847.0  609978946.0  626392880.0  643090131.0
# 2   33370804.0   34413603.0   35383028.0   36296111.0   37171922.0
# 3  390882979.0  401586651.0  412551299.0  423769930.0  435229381.0
# 4   26941773.0   27884380.0   28842482.0   29816769.0   30809787.0
#
#           2019         2020   pop_growth
# 0     106310.0     106766.0      52558.0
# 1  660046272.0  677243299.0  546406534.0
# 2   38041757.0   38928341.0   29931374.0
# 3  446911598.0  458803476.0  362407057.0
# 4   31825299.0   32866268.0   27411330.0
#
# [5 rows x 66 columns]

# %%
#Creating a new dataframe showing the relevant columns for this question#
q1_df = df[['Country Code', 'Region', 'IncomeGroup', 'TableName', '1960', '2020', 'pop_growth']]
q1_df.head(5)
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                      TableName         1960         2020   pop_growth
# 0                        Aruba      54208.0     106766.0      52558.0
# 1  Africa Eastern and Southern  130836765.0  677243299.0  546406534.0
# 2                  Afghanistan    8996967.0   38928341.0   29931374.0
# 3   Africa Western and Central   96396419.0  458803476.0  362407057.0
# 4                       Angola    5454938.0   32866268.0   27411330.0

# %%
#creating a new column to show the perctange increase in population growth between 2020 and 1960
q1_df['perct_growth'] = (q1_df['pop_growth']/q1_df['1960'])*100

# %%
#top 5 rows
q1_df.head(5)
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                      TableName         1960         2020   pop_growth  \
# 0                        Aruba      54208.0     106766.0      52558.0
# 1  Africa Eastern and Southern  130836765.0  677243299.0  546406534.0
# 2                  Afghanistan    8996967.0   38928341.0   29931374.0
# 3   Africa Western and Central   96396419.0  458803476.0  362407057.0
# 4                       Angola    5454938.0   32866268.0   27411330.0
#
#    perct_growth
# 0     96.956169
# 1    417.624613
# 2    332.682936
# 3    375.954896
# 4    502.504886

# %%
#sort values descending by percentage population growth#
q1_df.sort_values(by='perct_growth', ascending=False, inplace=True)

# %%
#round percentage population growth to 1 decimal number
q1_df['perct_growth'] = q1_df['perct_growth'].round(1)

# %%
#creating a dataframe showcasing the top 5 countries with the highest population growth#
top_perc_incre = q1_df.head(5)
top_perc_incre
# Out:
#     Country Code                      Region          IncomeGroup  \
# 8            ARE  Middle East & North Africa          High income
# 200          QAT  Middle East & North Africa          High income
# 127          KWT  Middle East & North Africa          High income
# 225          SXM   Latin America & Caribbean          High income
# 56           DJI  Middle East & North Africa  Lower middle income
#
#                      TableName      1960       2020  pop_growth  perct_growth
# 8         United Arab Emirates   92417.0  9890400.0   9797983.0       10601.9
# 200                      Qatar   47383.0  2881060.0   2833677.0        5980.4
# 127                     Kuwait  269026.0  4270563.0   4001537.0        1487.4
# 225  Sint Maarten (Dutch part)    2833.0    40812.0     37979.0        1340.6
# 56                    Djibouti   83634.0   988002.0    904368.0        1081.3

# %%
#barchart showing the top 5 countries with highest population growth#
plt.figure(figsize=(6,4))
ax = sns.barplot(x='perct_growth', y='TableName', data=top_perc_incre)
ax.set_xlabel('Percentage Growth')
ax.set_ylabel('Country', rotation =45)
ax.set_title('\n\nTop 5 Countries with the Highest Population Growth in Last 60 Years\n')
plt.show()

# %%
#reseting index#
new = top_perc_incre.reset_index()

# %%
#confirming our index has been reset#
new
# Out:
#    index Country Code                      Region          IncomeGroup  \
# 0      8          ARE  Middle East & North Africa          High income
# 1    200          QAT  Middle East & North Africa          High income
# 2    127          KWT  Middle East & North Africa          High income
# 3    225          SXM   Latin America & Caribbean          High income
# 4     56          DJI  Middle East & North Africa  Lower middle income
#
#                    TableName      1960       2020  pop_growth  perct_growth
# 0       United Arab Emirates   92417.0  9890400.0   9797983.0       10601.9
# 1                      Qatar   47383.0  2881060.0   2833677.0        5980.4
# 2                     Kuwait  269026.0  4270563.0   4001537.0        1487.4
# 3  Sint Maarten (Dutch part)    2833.0    40812.0     37979.0        1340.6
# 4                   Djibouti   83634.0   988002.0    904368.0        1081.3

# %%
#drafting out the details of the region and country with highest growth#
top_region_country = new.loc[0, ['Region', 'TableName', 'perct_growth']]
top_region_country
# Out:
# Region          Middle East & North Africa
# TableName             United Arab Emirates
# perct_growth                       10601.9
# Name: 0, dtype: object

# %%
#stating the country and region with highest population growth and its value#
print(f'{top_region_country[1]} is the Country with the highest population in {top_region_country[0]} Region  with a growth of {top_region_country[2]}%')
# Out:
# United Arab Emirates is the Country with the highest population in Middle East & North Africa Region  with a growth of 10601.9%

# %% [markdown]
# 2. •	Determine the trend of population growth worldwide in the last 60 years

# %%
#having an overview of our dataset again
df.head(5)
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                      TableName         1960         1961         1962  \
# 0                        Aruba      54208.0      55434.0      56234.0
# 1  Africa Eastern and Southern  130836765.0  134159786.0  137614644.0
# 2                  Afghanistan    8996967.0    9169406.0    9351442.0
# 3   Africa Western and Central   96396419.0   98407221.0  100506960.0
# 4                       Angola    5454938.0    5531451.0    5608499.0
#
#           1963         1964         1965  ...         2012         2013  \
# 0      56699.0      57029.0      57357.0  ...     102565.0     103165.0
# 1  141202036.0  144920186.0  148769974.0  ...  547482863.0  562601578.0
# 2    9543200.0    9744772.0    9956318.0  ...   31161378.0   32269592.0
# 3  102691339.0  104953470.0  107289875.0  ...  370243017.0  380437896.0
# 4    5679409.0    5734995.0    5770573.0  ...   25107925.0   26015786.0
#
#           2014         2015         2016         2017         2018  \
# 0     103776.0     104339.0     104865.0     105361.0     105846.0
# 1  578075373.0  593871847.0  609978946.0  626392880.0  643090131.0
# 2   33370804.0   34413603.0   35383028.0   36296111.0   37171922.0
# 3  390882979.0  401586651.0  412551299.0  423769930.0  435229381.0
# 4   26941773.0   27884380.0   28842482.0   29816769.0   30809787.0
#
#           2019         2020   pop_growth
# 0     106310.0     106766.0      52558.0
# 1  660046272.0  677243299.0  546406534.0
# 2   38041757.0   38928341.0   29931374.0
# 3  446911598.0  458803476.0  362407057.0
# 4   31825299.0   32866268.0   27411330.0
#
# [5 rows x 66 columns]

# %%
#checking out the columns
df.columns
# Out:
# Index(['Country Code', 'Region', 'IncomeGroup', 'TableName', '1960', '1961',
#        '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970',
#        '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979',
#        '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', 'pop_growth'],
#       dtype='object')

# %%
#pulling out necessary columns
years = df.iloc[:, 4:65]
years.head()
# Out:
#           1960         1961         1962         1963         1964  \
# 0      54208.0      55434.0      56234.0      56699.0      57029.0
# 1  130836765.0  134159786.0  137614644.0  141202036.0  144920186.0
# 2    8996967.0    9169406.0    9351442.0    9543200.0    9744772.0
# 3   96396419.0   98407221.0  100506960.0  102691339.0  104953470.0
# 4    5454938.0    5531451.0    5608499.0    5679409.0    5734995.0
#
#           1965         1966         1967         1968         1969  ...  \
# 0      57357.0      57702.0      58044.0      58377.0      58734.0  ...
# 1  148769974.0  152752671.0  156876454.0  161156430.0  165611760.0  ...
# 2    9956318.0   10174840.0   10399936.0   10637064.0   10893772.0  ...
# 3  107289875.0  109701811.0  112195950.0  114781116.0  117468741.0  ...
# 4    5770573.0    5781305.0    5774440.0    5771973.0    5803677.0  ...
#
#           2011         2012         2013         2014         2015  \
# 0     102050.0     102565.0     103165.0     103776.0     104339.0
# 1  532760424.0  547482863.0  562601578.0  578075373.0  593871847.0
# 2   30117411.0   31161378.0   32269592.0   33370804.0   34413603.0
# 3  360285439.0  370243017.0  380437896.0  390882979.0  401586651.0
# 4   24220660.0   25107925.0   26015786.0   26941773.0   27884380.0
#
#           2016         2017         2018         2019         2020
# 0     104865.0     105361.0     105846.0     106310.0     106766.0
# 1  609978946.0  626392880.0  643090131.0  660046272.0  677243299.0
# 2   35383028.0   36296111.0   37171922.0   38041757.0   38928341.0
# 3  412551299.0  423769930.0  435229381.0  446911598.0  458803476.0
# 4   28842482.0   29816769.0   30809787.0   31825299.0   32866268.0
#
# [5 rows x 61 columns]

# %%
#transposing the columns
tr_years = years.transpose()
tr_years.shape
# Out:
# (61, 266)

# %%
#summing up population accross all countries
tr_years['total_pop'] = tr_years.sum(axis=1)
tr_years.head()
# Out:
#             0            1          2            3          4          5  \
# 1960  54208.0  130836765.0  8996967.0   96396419.0  5454938.0  1608800.0
# 1961  55434.0  134159786.0  9169406.0   98407221.0  5531451.0  1659800.0
# 1962  56234.0  137614644.0  9351442.0  100506960.0  5608499.0  1711319.0
# 1963  56699.0  141202036.0  9543200.0  102691339.0  5679409.0  1762621.0
# 1964  57029.0  144920186.0  9744772.0  104953470.0  5734995.0  1814135.0
#
#             6            7         8           9  ...         257      258  \
# 1960  13410.0   92197715.0   92417.0  20481781.0  ...  32670048.0  63689.0
# 1961  14378.0   94724540.0  100801.0  20817270.0  ...  33666111.0  65700.0
# 1962  15379.0   97334438.0  112112.0  21153042.0  ...  34683410.0  67793.0
# 1963  16407.0  100034191.0  125130.0  21488916.0  ...  35721213.0  69944.0
# 1964  17466.0  102832792.0  138049.0  21824427.0  ...  36780001.0  72116.0
#
#                259       260        261        262         263        264  \
# 1960  3.032156e+09  108627.0   947000.0  5315351.0  17099836.0  3070780.0
# 1961  3.071596e+09  112112.0   966000.0  5393034.0  17524533.0  3164330.0
# 1962  3.124561e+09  115768.0   994000.0  5473671.0  17965733.0  3260645.0
# 1963  3.189656e+09  119552.0  1022000.0  5556767.0  18423157.0  3360099.0
# 1964  3.255146e+09  123346.0  1050000.0  5641598.0  18896303.0  3463211.0
#
#             265     total_pop
# 1960  3776679.0  3.097025e+10
# 1961  3905038.0  3.137868e+10
# 1962  4039209.0  3.193552e+10
# 1963  4178726.0  3.262729e+10
# 1964  4322854.0  3.332465e+10
#
# [5 rows x 267 columns]

# %%
#resetting index
tr_years.reset_index(inplace=True)

# %%
#overview of the dataset
tr_years.head()
# Out:
#   index        0            1          2            3          4          5  \
# 0  1960  54208.0  130836765.0  8996967.0   96396419.0  5454938.0  1608800.0
# 1  1961  55434.0  134159786.0  9169406.0   98407221.0  5531451.0  1659800.0
# 2  1962  56234.0  137614644.0  9351442.0  100506960.0  5608499.0  1711319.0
# 3  1963  56699.0  141202036.0  9543200.0  102691339.0  5679409.0  1762621.0
# 4  1964  57029.0  144920186.0  9744772.0  104953470.0  5734995.0  1814135.0
#
#          6            7         8  ...         257      258           259  \
# 0  13410.0   92197715.0   92417.0  ...  32670048.0  63689.0  3.032156e+09
# 1  14378.0   94724540.0  100801.0  ...  33666111.0  65700.0  3.071596e+09
# 2  15379.0   97334438.0  112112.0  ...  34683410.0  67793.0  3.124561e+09
# 3  16407.0  100034191.0  125130.0  ...  35721213.0  69944.0  3.189656e+09
# 4  17466.0  102832792.0  138049.0  ...  36780001.0  72116.0  3.255146e+09
#
#         260        261        262         263        264        265  \
# 0  108627.0   947000.0  5315351.0  17099836.0  3070780.0  3776679.0
# 1  112112.0   966000.0  5393034.0  17524533.0  3164330.0  3905038.0
# 2  115768.0   994000.0  5473671.0  17965733.0  3260645.0  4039209.0
# 3  119552.0  1022000.0  5556767.0  18423157.0  3360099.0  4178726.0
# 4  123346.0  1050000.0  5641598.0  18896303.0  3463211.0  4322854.0
#
#       total_pop
# 0  3.097025e+10
# 1  3.137868e+10
# 2  3.193552e+10
# 3  3.262729e+10
# 4  3.332465e+10
#
# [5 rows x 268 columns]

# %%
#pulling out needed columns
trend_60years = tr_years.iloc[:, [0,267]]
trend_60years.head()
# Out:
#   index     total_pop
# 0  1960  3.097025e+10
# 1  1961  3.137868e+10
# 2  1962  3.193552e+10
# 3  1963  3.262729e+10
# 4  1964  3.332465e+10

# %%
#renaming columns
trend_60years.rename(columns={'index': 'Year', 'total_pop': 'Population'}, inplace=True)

# %%
#top rows
trend_60years.head()
# Out:
#    Year    Population
# 0  1960  3.097025e+10
# 1  1961  3.137868e+10
# 2  1962  3.193552e+10
# 3  1963  3.262729e+10
# 4  1964  3.332465e+10

# %%
#check for data types
trend_60years.dtypes
# Out:
# Year           object
# Population    float64
# dtype: object

# %%
#Change Year data type
trend_60years['Year'] = pd.to_datetime(trend_60years['Year']).dt.year

# %%
#recheck the data type
trend_60years.dtypes
# Out:
# Year            int32
# Population    float64
# dtype: object

# %%
#top rows
trend_60years.head()
# Out:
#    Year    Population
# 0  1960  3.097025e+10
# 1  1961  3.137868e+10
# 2  1962  3.193552e+10
# 3  1963  3.262729e+10
# 4  1964  3.332465e+10

# %%
#rename columns
trend_60years.rename(columns={'Year': 'Date'}, inplace=True)

# %%
#reset index
trend_60years.set_index('Date', inplace=True)

# %%
#top rows
trend_60years.head()
# Out:
#         Population
# Date
# 1960  3.097025e+10
# 1961  3.137868e+10
# 1962  3.193552e+10
# 1963  3.262729e+10
# 1964  3.332465e+10

# %%
#plot the trend of population worldwide in last 60 years
plt.figure(figsize=(10,5))
sns.lineplot(x= trend_60years.index, y='Population', data=trend_60years)
plt.xticks(rotation=45)
plt.xlabel('Year')
plt.ylabel('Population\n', rotation = 45)
plt.title('Population Growth Worldwide in the Last 60 Years')
plt.show()

# %% [markdown]
# 3. Forecast world population in next 30 years

# %%
#determine best pdq and seasonal parameters
auto_model = pm.auto_arima(trend_60years['Population'], start_p=0, start_q=0,
                          max_p=5, max_q=5, seasonal=False,
                          d=None, stepwise=True, trace = True,
                          error_action='ignore',
                          suppress_warnings=True, information_criterion='aic')
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=2196.694, Time=0.08 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=2183.656, Time=0.03 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=2222.621, Time=0.04 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=2200.826, Time=0.02 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=2118.105, Time=0.17 sec
#  ARIMA(3,2,0)(0,0,0)[0] intercept   : AIC=2129.930, Time=0.23 sec
#  ARIMA(2,2,1)(0,0,0)[0] intercept   : AIC=2129.601, Time=0.15 sec
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=2141.717, Time=0.18 sec
#  ARIMA(3,2,1)(0,0,0)[0] intercept   : AIC=2131.201, Time=0.35 sec
#  ARIMA(2,2,0)(0,0,0)[0]             : AIC=2122.219, Time=0.04 sec
#
# Best model:  ARIMA(2,2,0)(0,0,0)[0] intercept
# Total fit time: 1.324 seconds

# %%
#auto model summary
print(auto_model.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   61
# Model:               SARIMAX(2, 2, 0)   Log Likelihood               -1055.053
# Date:                Thu, 22 Aug 2024   AIC                           2118.105
# Time:                        10:32:38   BIC                           2126.415
# Sample:                             0   HQIC                          2121.349
#                                  - 61
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   3.208e+06   1.51e-11   2.12e+17      0.000    3.21e+06    3.21e+06
# ar.L1         -0.0091      0.017     -0.553      0.581      -0.041       0.023
# ar.L2         -0.0043      0.006     -0.667      0.505      -0.017       0.008
# sigma2      1.789e+14   1.98e-18   9.05e+31      0.000    1.79e+14    1.79e+14
# ===================================================================================
# Ljung-Box (L1) (Q):                  15.97   Jarque-Bera (JB):                 0.24
# Prob(Q):                              0.00   Prob(JB):                         0.89
# Heteroskedasticity (H):               0.38   Skew:                             0.10
# Prob(H) (two-sided):                  0.04   Kurtosis:                         2.76
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.45e+49. Standard errors may be unstable.

# %%
#fit the model
best_model = auto_model.fit(trend_60years['Population'])

# %%
#forecast for next 30 years
forecast = best_model.predict(n_periods=30)

# %%
#generate future date range
forecast_years = pd.date_range(start='2021-01-01', periods=30, freq='Y').year
forecast_years
# Out:
# Index([2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032,
#        2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044,
#        2045, 2046, 2047, 2048, 2049, 2050],
#       dtype='int32')

# %%
#create dataframe with forecasted values
forecast_df = pd.DataFrame({'Date': forecast_years, 'Population': forecast})

# %%
#top rows
forecast_df.head()
# Out:
#     Date    Population
# 61  2021  8.477951e+10
# 62  2022  8.574818e+10
# 63  2023  8.672001e+10
# 64  2024  8.769501e+10
# 65  2025  8.867317e+10

# %%
#reset index
forecast_df.set_index('Date', inplace=True)
forecast_df
# Out:
#         Population
# Date
# 2021  8.477951e+10
# 2022  8.574818e+10
# 2023  8.672001e+10
# 2024  8.769501e+10
# 2025  8.867317e+10
# 2026  8.965450e+10
# 2027  9.063899e+10
# 2028  9.162665e+10
# 2029  9.261747e+10
# 2030  9.361146e+10
# 2031  9.460862e+10
# 2032  9.560894e+10
# 2033  9.661242e+10
# 2034  9.761907e+10
# 2035  9.862889e+10
# 2036  9.964187e+10
# 2037  1.006580e+11
# 2038  1.016773e+11
# 2039  1.026998e+11
# 2040  1.037254e+11
# 2041  1.047542e+11
# 2042  1.057862e+11
# 2043  1.068214e+11
# 2044  1.078597e+11
# 2045  1.089011e+11
# 2046  1.099458e+11
# 2047  1.109936e+11
# 2048  1.120445e+11
# 2049  1.130987e+11
# 2050  1.141559e+11

# %%
#plot the actual and forecast values
plt.figure(figsize=(10,5))
plt.plot(trend_60years, label='Actual', color = 'blue')
plt.plot(forecast_df, label='Forecast', color = 'red', linestyle='--')
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Population Forecast for the Next 10 Years\n')
plt.legend()
plt.show()

# %% [markdown]
# 4. •	What is the relationship between income group and population growth in last 60 years.

# %%
#top rows
df.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                      TableName         1960         1961         1962  \
# 0                        Aruba      54208.0      55434.0      56234.0
# 1  Africa Eastern and Southern  130836765.0  134159786.0  137614644.0
# 2                  Afghanistan    8996967.0    9169406.0    9351442.0
# 3   Africa Western and Central   96396419.0   98407221.0  100506960.0
# 4                       Angola    5454938.0    5531451.0    5608499.0
#
#           1963         1964         1965  ...         2012         2013  \
# 0      56699.0      57029.0      57357.0  ...     102565.0     103165.0
# 1  141202036.0  144920186.0  148769974.0  ...  547482863.0  562601578.0
# 2    9543200.0    9744772.0    9956318.0  ...   31161378.0   32269592.0
# 3  102691339.0  104953470.0  107289875.0  ...  370243017.0  380437896.0
# 4    5679409.0    5734995.0    5770573.0  ...   25107925.0   26015786.0
#
#           2014         2015         2016         2017         2018  \
# 0     103776.0     104339.0     104865.0     105361.0     105846.0
# 1  578075373.0  593871847.0  609978946.0  626392880.0  643090131.0
# 2   33370804.0   34413603.0   35383028.0   36296111.0   37171922.0
# 3  390882979.0  401586651.0  412551299.0  423769930.0  435229381.0
# 4   26941773.0   27884380.0   28842482.0   29816769.0   30809787.0
#
#           2019         2020   pop_growth
# 0     106310.0     106766.0      52558.0
# 1  660046272.0  677243299.0  546406534.0
# 2   38041757.0   38928341.0   29931374.0
# 3  446911598.0  458803476.0  362407057.0
# 4   31825299.0   32866268.0   27411330.0
#
# [5 rows x 66 columns]

# %%
#group population growth by income group
socio_df = df.groupby('IncomeGroup')['pop_growth'].mean().sort_values(ascending=False).round(1)
socio_df
# Out:
# IncomeGroup
# Lower middle income    43256764.3
# Upper middle income    25040155.1
# Low income             20185686.1
# High income             5598284.9
# Name: pop_growth, dtype: float64

# %% [markdown]
# High income countries have the lowest population growth followed by Low income countries. On the other hand, middle income countries have the highest population growth

# %%
#reset index
df_socio = socio_df.reset_index()
df_socio
# Out:
#            IncomeGroup  pop_growth
# 0  Lower middle income  43256764.3
# 1  Upper middle income  25040155.1
# 2           Low income  20185686.1
# 3          High income   5598284.9

# %%
print(f'{socio_df.index[0]} has the highest population growth with a value of {socio_df[0]}')
# Out:
# Lower middle income has the highest population growth with a value of 43256764.3

# %%
sns.barplot(x='IncomeGroup', y='pop_growth', data=df_socio)
plt.xticks(rotation=45)
plt.xlabel('Income Group')
plt.ylabel('Population Growth\n\n', rotation = 50)
plt.title('Population Growth by Income Group\n')
plt.show()

# %% [markdown]
# 5. •	Determine the percentage change in population growth over the last 60 years in Nigeria

# %%
#top rows
Naija_df.head()
# Out:
#    Year  Population
# 0  1960  45138460.0
# 1  1961  46063570.0
# 2  1962  47029818.0
# 3  1963  48032932.0
# 4  1964  49066762.0

# %%
#create new column to show growth change
def Pop_Growth(row):
  if row.name == 0:
    return 0
  else:
      return row['Population'] - Naija_df.loc[row.name-1, 'Population']

Naija_df['Growth_Increase'] = Naija_df.apply(Pop_Growth, axis=1)
Naija_df.head()
# Out:
#    Year  Population  Growth_Increase
# 0  1960  45138460.0              0.0
# 1  1961  46063570.0         925110.0
# 2  1962  47029818.0         966248.0
# 3  1963  48032932.0        1003114.0
# 4  1964  49066762.0        1033830.0

# %%
#create new column to show percentage growth change
def growth_percent(row):
  if row.name == 0:
    return 0
  else:
    return (row['Growth_Increase']/Naija_df.loc[row.name-1, 'Population'])*100

Naija_df['Percent_Growth'] = Naija_df.apply(growth_percent, axis=1).round(2)
Naija_df.head()
# Out:
#    Year  Population  Growth_Increase  Percent_Growth
# 0  1960  45138460.0              0.0            0.00
# 1  1961  46063570.0         925110.0            2.05
# 2  1962  47029818.0         966248.0            2.10
# 3  1963  48032932.0        1003114.0            2.13
# 4  1964  49066762.0        1033830.0            2.15

# %% [markdown]
# 6. •	Determine the percentage growth between each year over the last 60 years and sort descending.

# %%
#sort values descending
sorted_naijadf = Naija_df.sort_values(by='Percent_Growth', ascending=False)
sorted_naijadf
# Out:
#     Year  Population  Growth_Increase  Percent_Growth
# 18  1978  69271915.0        2068781.0            3.08
# 17  1977  67203134.0        1981755.0            3.04
# 19  1979  71361141.0        2089226.0            3.02
# 16  1976  65221379.0        1847090.0            2.91
# 20  1980  73423646.0        2062505.0            2.89
# ..   ...         ...              ...             ...
# 4   1964  49066762.0        1033830.0            2.15
# 3   1963  48032932.0        1003114.0            2.13
# 2   1962  47029818.0         966248.0            2.10
# 1   1961  46063570.0         925110.0            2.05
# 0   1960  45138460.0              0.0            0.00
#
# [61 rows x 4 columns]

# %% [markdown]
# 7. •	Determine the trend of population growth in last 60 years  in Nigeria

# %%
#top 20 rows
Naija_df.head(20)
# Out:
#     Year  Population  Growth_Increase  Percent_Growth
# 0   1960  45138460.0              0.0            0.00
# 1   1961  46063570.0         925110.0            2.05
# 2   1962  47029818.0         966248.0            2.10
# 3   1963  48032932.0        1003114.0            2.13
# 4   1964  49066762.0        1033830.0            2.15
# 5   1965  50127920.0        1061158.0            2.16
# 6   1966  51217969.0        1090049.0            2.17
# 7   1967  52342231.0        1124262.0            2.20
# 8   1968  53506201.0        1163970.0            2.22
# 9   1969  54717035.0        1210834.0            2.26
# 10  1970  55982142.0        1265107.0            2.31
# 11  1971  57296988.0        1314846.0            2.35
# 12  1972  58665813.0        1368825.0            2.39
# 13  1973  60114615.0        1448802.0            2.47
# 14  1974  61677167.0        1562552.0            2.60
# 15  1975  63374289.0        1697122.0            2.75
# 16  1976  65221379.0        1847090.0            2.91
# 17  1977  67203134.0        1981755.0            3.04
# 18  1978  69271915.0        2068781.0            3.08
# 19  1979  71361141.0        2089226.0            3.02

# %%
#last 20 rows
Naija_df.tail(20)
# Out:
#     Year   Population  Growth_Increase  Percent_Growth
# 41  2001  125394046.0        3110193.0            2.54
# 42  2002  128596079.0        3202033.0            2.55
# 43  2003  131900634.0        3304555.0            2.57
# 44  2004  135320420.0        3419786.0            2.59
# 45  2005  138865014.0        3544594.0            2.62
# 46  2006  142538305.0        3673291.0            2.65
# 47  2007  146339971.0        3801666.0            2.67
# 48  2008  150269622.0        3929651.0            2.69
# 49  2009  154324939.0        4055317.0            2.70
# 50  2010  158503203.0        4178264.0            2.71
# 51  2011  162805080.0        4301877.0            2.71
# 52  2012  167228803.0        4423723.0            2.72
# 53  2013  171765819.0        4537016.0            2.71
# 54  2014  176404931.0        4639112.0            2.70
# 55  2015  181137454.0        4732523.0            2.68
# 56  2016  185960244.0        4822790.0            2.66
# 57  2017  190873247.0        4913003.0            2.64
# 58  2018  195874685.0        5001438.0            2.62
# 59  2019  200963603.0        5088918.0            2.60
# 60  2020  206139587.0        5175984.0            2.58

# %%
#population growth in Nigeria over the last 60 years
plt.figure(figsize=(10,6))
sns.lineplot(x='Year', y='Growth_Increase', data=Naija_df)
plt.title('Population growth rate change in Nigeria over the last 60 years\n')
plt.xlim(1960)
plt.ylabel('Population Growth\n\n', rotation = 70)
plt.xlabel('Year')
plt.show()

# %%
#percentage population growth in Nigeria over the last 60 years
plt.figure(figsize=(10,6))
sns.lineplot(x='Year', y='Percent_Growth', data=Naija_df)
plt.title('Percentage population growth in Nigeria over the last 60 years\n')
plt.xlim(1960)
plt.ylabel('Percentage Growth\n\n', rotation = 70)
plt.xlabel('Year')
plt.show()

# %% [markdown]
# 8. •	Forecast Nigeria population in next 10 years.

# %%
#top rows
Naija_df.head()
# Out:
#    Year  Population  Growth_Increase  Percent_Growth
# 0  1960  45138460.0              0.0            0.00
# 1  1961  46063570.0         925110.0            2.05
# 2  1962  47029818.0         966248.0            2.10
# 3  1963  48032932.0        1003114.0            2.13
# 4  1964  49066762.0        1033830.0            2.15

# %%
#create a new dataframe with Year and Population
q8_df = Naija_df[['Year', 'Population']]
q8_df.head()
# Out:
#    Year  Population
# 0  1960  45138460.0
# 1  1961  46063570.0
# 2  1962  47029818.0
# 3  1963  48032932.0
# 4  1964  49066762.0

# %%
#rename columns
q8_df.rename(columns={'Year': 'Date'}, inplace=True)

# %%
#reset index
q8_df.set_index('Date', inplace=True)

# %%
#top rows
q8_df.head()
# Out:
#       Population
# Date
# 1960  45138460.0
# 1961  46063570.0
# 1962  47029818.0
# 1963  48032932.0
# 1964  49066762.0

# %%
#determine the best pdq and seasonal parameters
auto_model = pm.auto_arima(q8_df['Population'], start_p=0, start_q=0,
                          max_p=5, max_q=5, seasonal=False,
                          d=None, stepwise=True, trace = True,
                          error_action='ignore',
                          suppress_warnings=True, information_criterion='aic')
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=1429.842, Time=0.03 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=1488.105, Time=0.12 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=1431.237, Time=0.05 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=1507.147, Time=0.02 sec
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=1740.302, Time=0.27 sec
#
# Best model:  ARIMA(0,2,0)(0,0,0)[0] intercept
# Total fit time: 0.498 seconds

# %%
#print auto model summary
print(auto_model.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   61
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                -712.921
# Date:                Thu, 22 Aug 2024   AIC                           1429.842
# Time:                        10:36:43   BIC                           1433.997
# Sample:                             0   HQIC                          1431.464
#                                  - 61
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   7.205e+04   5950.344     12.108      0.000    6.04e+04    8.37e+04
# sigma2      1.832e+09   3.58e+08      5.118      0.000    1.13e+09    2.53e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  51.14   Jarque-Bera (JB):                 2.45
# Prob(Q):                              0.00   Prob(JB):                         0.29
# Heteroskedasticity (H):               0.57   Skew:                            -0.50
# Prob(H) (two-sided):                  0.21   Kurtosis:                         3.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#fit the model
naija_bestmodel = auto_model.fit(q8_df['Population'])

# %%
#forecast for next 30 years
naija_forecast = naija_bestmodel.predict(n_periods=30)

# %%
#generate the date range for the forecast
naija_forecastyears = pd.date_range(start='2021-01-01', periods=30, freq='Y').year
naija_forecastyears
# Out:
# Index([2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032,
#        2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044,
#        2045, 2046, 2047, 2048, 2049, 2050],
#       dtype='int32')

# %%
#create a dataframe with generated values
forecastdf = pd.DataFrame({'Date': naija_forecastyears, 'Population': naija_forecast})
forecastdf
# Out:
#     Date    Population
# 61  2021  2.113876e+08
# 62  2022  2.167077e+08
# 63  2023  2.220998e+08
# 64  2024  2.275640e+08
# 65  2025  2.331002e+08
# 66  2026  2.387085e+08
# 67  2027  2.443888e+08
# 68  2028  2.501412e+08
# 69  2029  2.559656e+08
# 70  2030  2.618621e+08
# 71  2031  2.678306e+08
# 72  2032  2.738712e+08
# 73  2033  2.799838e+08
# 74  2034  2.861685e+08
# 75  2035  2.924252e+08
# 76  2036  2.987540e+08
# 77  2037  3.051548e+08
# 78  2038  3.116276e+08
# 79  2039  3.181725e+08
# 80  2040  3.247895e+08
# 81  2041  3.314785e+08
# 82  2042  3.382396e+08
# 83  2043  3.450727e+08
# 84  2044  3.519778e+08
# 85  2045  3.589550e+08
# 86  2046  3.660043e+08
# 87  2047  3.731256e+08
# 88  2048  3.803189e+08
# 89  2049  3.875843e+08
# 90  2050  3.949218e+08

# %%
#reset index
forecastdf.set_index('Date', inplace=True)

# %%
#plot the trend of Nigeria population growth over the last 60 years
plt.figure(figsize=(10,5))
sns.lineplot(x= q8_df.index, y='Population', data=q8_df)
plt.xticks(rotation=45)
plt.xlim(1960)
plt.xlabel('Year')
plt.ylabel('Population\n\n', rotation = 45)
plt.title('Nigeria population growth over last 60years\n')
plt.show()

# %%
#plot the forecast
plt.figure(figsize=(10,5))
plt.plot(q8_df, label='Actual', color = 'blue')
plt.plot(forecastdf, label='Forecast', color = 'red', linestyle='--')
plt.xlim(1960)
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Nigeria population Forecast for the Next 30 Years\n')
plt.legend()
plt.show()
